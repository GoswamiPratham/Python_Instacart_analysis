# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Question 1

# %%
path=r'C:\Users\goswa\Desktop\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\goswa\Desktop\Instacart Basket Analysis\Data\Prepared Data\orders_products_merged2.pkl')

# %% [markdown]
# # Question 2

# %%
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Quesiton 3

# %%
# the mean for the entire data set is smaller than the mean for the subset except for a few departments

# %% [markdown]
# # Question 4

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_10284\1681540670.py:1: FutureWarning: The provided callable <function amax at 0x000001F753671BC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#       busiest_day    busiest_days busiest_period_of_day  max_order
# 0  Regularly busy  Regularly days        Average orders         10
# 1  Regularly busy    Slowest days        Average orders         10
# 2  Regularly busy    Slowest days           Most orders         10
# 3      Least busy    Slowest days        Average orders         10
# 4      Least busy    Slowest days           Most orders         10

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'order_number', 'loyalty_flag']].sample(10)
# Out:
#           user_id  order_number      loyalty_flag
# 23371501    16513             8  Regular customer
# 14996308   179715            39    Loyal customer
# 2415113     39053             3  Regular customer
# 1332374    146874             5  Regular customer
# 14849840    90508            11  Regular customer
# 18248887   163003            41    Loyal customer
# 30270165   163695             8  Regular customer
# 30403762   151837             7      New customer
# 16324681   169927            21  Regular customer
# 23700025   204302             3  Regular customer

# %% [markdown]
# # Question 5

# %%
# find mean, maximum, and minimum for the 3 loyalty categories
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# # Question 6

# %%
# creat average_price column

# %%
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_10284\1521181374.py:1: FutureWarning: The provided callable <function mean at 0x000001F7536728E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  hour_ordered  \
# 0    2539329        1             1                   2             8
# 1    2398795        1             2                   3             7
# 2     473747        1             3                   3            12
# 3    2254736        1             4                   4             7
# 4     431534        1             5                   4            15
# 5    3367565        1             6                   2             7
# 6     550135        1             7                   1             9
# 7    3108588        1             8                   1            14
# 8    2295261        1             9                   1            16
# 9    2550362        1            10                   4             8
# 10   2968173       15            15                   1             9
# 11   1870022       15            17                   2            16
# 12   1911383       15            18                   2            11
# 13   2715276       15            21                   1             9
# 14    487368       15            22                   1            10
# 15   2293453       19             2                   5            14
# 16   1973799       19             5                   6            12
# 17    532817       19             7                   4            17
# 18   1573906       21            10                   3            10
# 19   1593000       31            10                   3             8
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
#
#    product_name  aisle_id  department_id  prices        price_range  \
# 0          Soda        77              7     9.0  Mid-range product
# 1          Soda        77              7     9.0  Mid-range product
# 2          Soda        77              7     9.0  Mid-range product
# 3          Soda        77              7     9.0  Mid-range product
# 4          Soda        77              7     9.0  Mid-range product
# 5          Soda        77              7     9.0  Mid-range product
# 6          Soda        77              7     9.0  Mid-range product
# 7          Soda        77              7     9.0  Mid-range product
# 8          Soda        77              7     9.0  Mid-range product
# 9          Soda        77              7     9.0  Mid-range product
# 10         Soda        77              7     9.0  Mid-range product
# 11         Soda        77              7     9.0  Mid-range product
# 12         Soda        77              7     9.0  Mid-range product
# 13         Soda        77              7     9.0  Mid-range product
# 14         Soda        77              7     9.0  Mid-range product
# 15         Soda        77              7     9.0  Mid-range product
# 16         Soda        77              7     9.0  Mid-range product
# 17         Soda        77              7     9.0  Mid-range product
# 18         Soda        77              7     9.0  Mid-range product
# 19         Soda        77              7     9.0  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day  max_order  \
# 0   Regularly busy  Regularly days        Average orders         10
# 1   Regularly busy    Slowest days        Average orders         10
# 2   Regularly busy    Slowest days           Most orders         10
# 3       Least busy    Slowest days        Average orders         10
# 4       Least busy    Slowest days           Most orders         10
# 5   Regularly busy  Regularly days        Average orders         10
# 6   Regularly busy    Busiest days        Average orders         10
# 7   Regularly busy    Busiest days           Most orders         10
# 8   Regularly busy    Busiest days        Average orders         10
# 9       Least busy    Slowest days        Average orders         10
# 10  Regularly busy    Busiest days        Average orders         22
# 11  Regularly busy  Regularly days        Average orders         22
# 12  Regularly busy  Regularly days           Most orders         22
# 13  Regularly busy    Busiest days        Average orders         22
# 14  Regularly busy    Busiest days           Most orders         22
# 15  Regularly busy  Regularly days           Most orders          9
# 16  Regularly busy  Regularly days           Most orders          9
# 17      Least busy    Slowest days        Average orders          9
# 18  Regularly busy    Slowest days           Most orders         33
# 19  Regularly busy    Slowest days        Average orders         20
#
#         loyalty_flag  average_price
# 0       New customer       6.367797
# 1       New customer       6.367797
# 2       New customer       6.367797
# 3       New customer       6.367797
# 4       New customer       6.367797
# 5       New customer       6.367797
# 6       New customer       6.367797
# 7       New customer       6.367797
# 8       New customer       6.367797
# 9       New customer       6.367797
# 10  Regular customer       3.980556
# 11  Regular customer       3.980556
# 12  Regular customer       3.980556
# 13  Regular customer       3.980556
# 14  Regular customer       3.980556
# 15      New customer       8.372059
# 16      New customer       8.372059
# 17      New customer       8.372059
# 18  Regular customer       7.012683
# 19  Regular customer       8.137793

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_10284\3814550370.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.head(4)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
#
#   product_name  ...  department_id  prices        price_range     busiest_day  \
# 0         Soda  ...              7     9.0  Mid-range product  Regularly busy
# 1         Soda  ...              7     9.0  Mid-range product  Regularly busy
# 2         Soda  ...              7     9.0  Mid-range product  Regularly busy
# 3         Soda  ...              7     9.0  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag average_price  \
# 0  Regularly days        Average orders        10  New customer      6.367797
# 1    Slowest days        Average orders        10  New customer      6.367797
# 2    Slowest days           Most orders        10  New customer      6.367797
# 3    Slowest days        Average orders        10  New customer      6.367797
#
#    spending_flag
# 0    Low spender
# 1    Low spender
# 2    Low spender
# 3    Low spender
#
# [4 rows x 21 columns]

# %% [markdown]
# # Question 7

# %%
# creating "median_orders" column 
ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_10284\2770631629.py:2: FutureWarning: The provided callable <function median at 0x000001F7537B3880> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  hour_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices        price_range     busiest_day  \
# 0         Soda  ...     9.0  Mid-range product  Regularly busy
# 1         Soda  ...     9.0  Mid-range product  Regularly busy
# 2         Soda  ...     9.0  Mid-range product  Regularly busy
# 3         Soda  ...     9.0  Mid-range product      Least busy
# 4         Soda  ...     9.0  Mid-range product      Least busy
#
#      busiest_days busiest_period_of_day max_order  loyalty_flag  \
# 0  Regularly days        Average orders        10  New customer
# 1    Slowest days        Average orders        10  New customer
# 2    Slowest days           Most orders        10  New customer
# 3    Slowest days        Average orders        10  New customer
# 4    Slowest days           Most orders        10  New customer
#
#    average_price spending_flag  median_orders
# 0       6.367797   Low spender           20.5
# 1       6.367797   Low spender           20.5
# 2       6.367797   Low spender           20.5
# 3       6.367797   Low spender           20.5
# 4       6.367797   Low spender           20.5
#
# [5 rows x 22 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\goswa\AppData\Local\Temp\ipykernel_10284\2105341910.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_orders'] > 10) & (ords_prods_merge['median_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %% [markdown]
# # Question 9

# %%
ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_3.0.pkl'))
